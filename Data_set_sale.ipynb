# %% [markdown]
# ![data.jpg](attachment:data.jpg)

# %%
import pandas as pd

# %%
data_1={"Products":"Cold Drinks", "Season":"summer", "Location":"Excellent","Competetion in Market":"Excellent", "Marketing":"high", "Consumer_Bahviour":"Good", "Discounted_price":"high", "Product_Quality":"good", "Product_Availability":"high","output":0.3}
data_2={"Products":"Cold Drinks", "Season":"Winter", "Location":"Good","Competetion in Market":"Excellent", "Marketing":"high", "Consumer_Bahviour":"Good", "Discounted_price":"medium", "Product_Quality":"good", "Product_Availability":"high","output":0.5}
data_3={"Products":"Cold Drinks", "Season":"summer", "Location":"Bad","Competetion in Market":"Excellent", "Marketing":"high", "Consumer_Bahviour":"Good", "Discounted_price":"low", "Product_Quality":"good", "Product_Availability":"high","output":0.3}
data_4={"Products":"Cold Drinks", "Season":"summer", "Location":"Excellent","Competetion in Market":"Excellent", "Marketing":"high", "Consumer_Bahviour":"Good", "Discounted_price":"high", "Product_Quality":"good", "Product_Availability":"high","output":0.6}
data_5 = {"Products":"Cold Drinks", "Season":"summer", "Location":"Excellent","Competetion in Market":"Excellent", "Marketing":"low", "Consumer_Bahviour":"bad", "Discounted_price":"low", "Product_Quality":"good", "Product_Availability":"high","output":0.4}
data_6= {"Products":"Cold Drinks", "Season":"summer", "Location":"Excellent","Competetion in Market":"Excellent", "Marketing":"high", "Consumer_Bahviour":"Good", "Discounted_price":"high", "Product_Quality":"good", "Product_Availability":"low","output":0.4}
data_7= {"Products":"Cold Drinks", "Season":"Winter", "Location":"Excellent","Competetion in Market":"bad", "Marketing":"high", "Consumer_Bahviour":"Good", "Discounted_price":"high", "Product_Quality":"good", "Product_Availability":"high","output":0.6}
data_8={"Products":"Cold Drinks", "Season":"summer", "Location":"Excellent","Competetion in Market":"Excellent", "Marketing":"high", "Consumer_Bahviour":"Good", "Discounted_price":"high", "Product_Quality":"good", "Product_Availability":"high","output":0.5}
data_9={"Products":"Cold Drinks", "Season":"summer", "Location":"Excellent","Competetion in Market":"Excellent", "Marketing":"high", "Consumer_Bahviour":"Good", "Discounted_price":"high", "Product_Quality":"good", "Product_Availability":"high","output":0.2}
data_10= {"Products":"Cold Drinks", "Season":"Winter", "Location":"Excellent","Competetion in Market":"Excellent", "Marketing":"medium", "Consumer_Bahviour":"Good", "Discounted_price":"low", "Product_Quality":"bad", "Product_Availability":"low","output":0.4}
data_list = [data_1, data_2, data_3, data_4, data_5, data_6, data_7, data_8, data_9, data_10]

df = pd.DataFrame(data_list)

print(df)
# Out:
#       Products  Season   Location Competetion in Market Marketing  \
# 0  Cold Drinks  summer  Excellent             Excellent      high
# 1  Cold Drinks  Winter       Good             Excellent      high
# 2  Cold Drinks  summer        Bad             Excellent      high
# 3  Cold Drinks  summer  Excellent             Excellent      high
# 4  Cold Drinks  summer  Excellent             Excellent       low
# 5  Cold Drinks  summer  Excellent             Excellent      high
# 6  Cold Drinks  Winter  Excellent                   bad      high
# 7  Cold Drinks  summer  Excellent             Excellent      high
# 8  Cold Drinks  summer  Excellent             Excellent      high
# 9  Cold Drinks  Winter  Excellent             Excellent    medium
#
#   Consumer_Bahviour Discounted_price Product_Quality Product_Availability  \
# 0              Good             high            good                 high
# 1              Good           medium            good                 high
# ...

# %%
df.plot

# %%
df.describe()
# Out:
#           output
# count  10.000000
# mean    0.420000
# std     0.131656
# min     0.200000
# 25%     0.325000
# 50%     0.400000
# 75%     0.500000
# max     0.600000

# %%
X = df.drop("output", axis='columns')
Y=df["output"]

# %%
Y.shape
# Out:
# (10,)

# %%
X.shape
# Out:
# (10, 9)

# %%
from sklearn.preprocessing import LabelEncoder
labelencoder = LabelEncoder()

# %%
df.columns
# Out:
# Index(['Products', 'Season', 'Location', 'Competetion in Market', 'Marketing',
#        'Consumer_Bahviour', 'Discounted_price', 'Product_Quality',
#        'Product_Availability', 'output'],
#       dtype='object')

# %%
df["Products"]= labelencoder.fit_transform(df["Products"])
df["Season"] = labelencoder.fit_transform(df["Season"])
df["Location"] = labelencoder.fit_transform(df["Location"])
df["Competetion in Market"] = labelencoder.fit_transform(df["Competetion in Market"])
df["Marketing"] = labelencoder.fit_transform(df["Marketing"])
df["Consumer_Bahviour"] = labelencoder.fit_transform(df["Consumer_Bahviour"])
df["Discounted_price"] =labelencoder.fit_transform(df["Discounted_price"])
df["Product_Quality"]= labelencoder.fit_transform(df["Product_Quality"])
df["Discounted_price"]=labelencoder.fit_transform(df["Discounted_price"])
df["Product_Availability"]=labelencoder.fit_transform(df["Product_Availability"])

# %%
df.shape
# Out:
# (10, 10)

# %%
from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split(X, Y, test_size=0.2,random_state = 10)

# %%
y_test.shape
# Out:
# (2,)

# %%
X_train.shape
# Out:
# (8, 9)

# %%
from time import time
# Import Linear Regression algorithm
from sklearn.linear_model import LinearRegression
from sklearn.metrics import mean_squared_error, mean_absolute_error

# Initiate the model
start = time()
lin_model = LinearRegression()
# Fit the model to our dataset
lin_model.fit(X_train,y_train)
y_preds = lin_model.predict(X_test)
end = time()
print(f"The duration of training is: {end-start}")
# Model accuracy
print(f"R_squared for the validation data is:{lin_model.score(X_test, y_test)}")
print(f"The mean squared error for the model is:{mean_squared_error(y_test, y_preds)} ")
print(f"The mean absolute error for the model is:{mean_absolute_error(y_test, y_preds)} ")
# Out:
# The duration of training is: 0.005681514739990234
# R_squared for the validation data is:-17.447479117841496
# The mean squared error for the model is:0.046118697794603716
# The mean absolute error for the model is:0.2060077519379846
